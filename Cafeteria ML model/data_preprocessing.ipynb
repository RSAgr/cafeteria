# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Faraz\Cafeteria ML model\Cafeteria Data .csv")
df.head(5)
# Out:
#              Timestamp What is the most visited cafeteria for you?  \
# 0  24/03/2025 12:52:49                                      Techno
# 1  24/03/2025 12:54:13                                          IC
# 2  24/03/2025 12:56:24                                          IC
# 3  24/03/2025 12:59:00                                          IC
# 4  24/03/2025 12:59:43                                          IC
#
#   What time visit the cafeteria most often?  \
# 0                                  18:30:00
# 1                                  19:00:00
# 2                                  17:30:00
# 3                                       NaN
# 4                                  19:00:00
#
#   How often do you visit the cafeteria near you?  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# ...

# %%
df.head(5)
# Out:
#              Timestamp What is the most visited cafeteria for you?  \
# 0  24/03/2025 12:52:49                                      Techno
# 1  24/03/2025 12:54:13                                          IC
# 2  24/03/2025 12:56:24                                          IC
# 3  24/03/2025 12:59:00                                          IC
# 4  24/03/2025 12:59:43                                          IC
#
#   What time visit the cafeteria most often?  \
# 0                                  18:30:00
# 1                                  19:00:00
# 2                                  17:30:00
# 3                                       NaN
# 4                                  19:00:00
#
#   How often do you visit the cafeteria near you?  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                               0
# What is the most visited cafeteria for you?                                                                                             0
# What time visit the cafeteria most often?                                                                                               8
# How often do you visit the cafeteria near you?                                                                                         71
# Which day of the week do you visit the cafeteria most often?                                                                            2
# For which kind of meals do you visit the cafeteria?                                                                                     0
# In what kind of weather do you most often visit the cafeteria                                                                           0
# ...

# %%
df.drop(['What do you feel is the most busiest time of the cafeterias you visit'], axis=1, inplace=True)
